# %% [markdown]
# # 1. Import and Install Dependencies

# %% [markdown]
# - Import _library_ yang diperlukan

# %%
import cv2
import time
import pygame
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mediapipe as mp
import joblib
from sklearn.preprocessing import StandardScaler
from pygame import mixer

mp_facemesh = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils
denormalize_coordinates = mp_drawing._normalized_to_pixel_coordinates

# %matplotlib inline
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.9.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # 2. Define the Function

# %% [markdown]
# - Mendefinisikan titik _landmark_ beserta indeksnya

# %%
# Landmark points corresponding to left eye
all_left_eye_idxs = list(mp_facemesh.FACEMESH_LEFT_EYE)
# flatten and remove duplicates
all_left_eye_idxs = set(np.ravel(all_left_eye_idxs)) 
 
# Landmark points corresponding to right eye
all_right_eye_idxs = list(mp_facemesh.FACEMESH_RIGHT_EYE)
all_right_eye_idxs = set(np.ravel(all_right_eye_idxs))
 
# Combined for plotting - Landmark points for both eye
all_idxs = all_left_eye_idxs.union(all_right_eye_idxs)
 
# The chosen 12 points:   P1,  P2,  P3,  P4,  P5,  P6
chosen_left_eye_idxs  = [362, 385, 387, 263, 373, 380]
chosen_right_eye_idxs = [33,  160, 158, 133, 153, 144]
all_chosen_idxs = chosen_left_eye_idxs + chosen_right_eye_idxs

# %% [markdown]
# - Mendefinisikan fungsi **distance** untuk menghitung jarak antara dua titik

# %%
def distance(point_1, point_2):
    """Calculate l2-norm between two points"""
    dist = sum([(i - j) ** 2 for i, j in zip(point_1, point_2)]) ** 0.5
    return dist

# %% [markdown]
# - Mendefinisikan fungsi **get_ear** untuk mengkalkulasi nilai *eye aspect ratio* untuk satu mata

# %%
def get_ear(landmarks, refer_idxs, frame_width, frame_height):
    """
    Calculate Eye Aspect Ratio for one eye.
 
    Args:
        landmarks: (list) Detected landmarks list
        refer_idxs: (list) Index positions of the chosen landmarks
                            in order P1, P2, P3, P4, P5, P6
        frame_width: (int) Width of captured frame
        frame_height: (int) Height of captured frame
 
    Returns:
        ear: (float) Eye aspect ratio
    """
    try:
        # Compute the euclidean distance between the horizontal
        coords_points = []
        for i in refer_idxs:
            lm = landmarks[i]
            coord = denormalize_coordinates(lm.x, lm.y, 
                                             frame_width, frame_height)
            coords_points.append(coord)
 
        # Eye landmark (x, y)-coordinates
        P2_P6 = distance(coords_points[1], coords_points[5])
        P3_P5 = distance(coords_points[2], coords_points[4])
        P1_P4 = distance(coords_points[0], coords_points[3])
 
        # Compute the eye aspect ratio
        ear = (P2_P6 + P3_P5) / (2.0 * P1_P4)
 
    except:
        ear = 0.0
        coords_points = None
 
    return ear, coords_points

# %% [markdown]
# - Mendefinisikan fungsi **calculate_avg_ear** untuk mengkalkulasi nilai rata - rata *eye aspect ratio* untuk kedua mata

# %%
def calculate_avg_ear(landmarks, left_eye_idxs, right_eye_idxs, image_w, image_h):
    """Calculate Eye aspect ratio"""
 
    left_ear, left_lm_coordinates = get_ear(
                                      landmarks, 
                                      left_eye_idxs, 
                                      image_w, 
                                      image_h
                                    )
    right_ear, right_lm_coordinates = get_ear(
                                      landmarks, 
                                      right_eye_idxs, 
                                      image_w, 
                                      image_h
                                    )
    Avg_EAR = (left_ear + right_ear) / 2.0
 
    return Avg_EAR, (left_lm_coordinates, right_lm_coordinates)

# %% [markdown]
# - Mendefinisikan variabel untuk _library_ mixer

# %%
mixer.init()
step_sound = mixer.Sound('../Sounds/step.wav')
step_sound.set_volume(0.1)
alarm_sound = mixer.Sound('../Sounds/ping.mp3')
alarm_sound.set_volume(0.1)
start_sound = mixer.Sound('../Sounds/mh_notification.mp3')
start_sound.set_volume(0.1)

# %% [markdown]
# # 3. Load Model

# %% [markdown]
# - Memuat model SVM dan _feature scaling_ dengan akurasi terbaik yang diperoleh pada tahap pelatihan dan pengujian

# %%
# Load the pre-trained SVC model
model_path = r"D:\UGM\Teknik Fisika 18\[Someone]\Coding\Kode Final (Fix)\Models\Pelatihan_2\variation_14"

loaded_svc_model = joblib.load(os.path.join(model_path, 'svc_model_14.pkl'))
loaded_scaler = joblib.load(os.path.join(model_path, 'standar_scaler_14.pkl'))

# %% [markdown]
# # 4. Make Detection

# %% [markdown]
# ## 4.1. Make Detection to Video File

# %% [markdown]
# - Mendefinisikan variabel yang digunakan dalam proses deteksi

# %%
data_EAR = []
data_EAR_awake = []
data_EAR_drowsy = []
data_status = []
data_duration = []

max_drowsy_frame = 45

# %% [markdown]
# - Menjalankan proses deteksi pada _input_ berupa data video

# %%
drowsy_frame = 0
duration = 0

# change with your video path
video_path = r"D:\UGM\Teknik Fisika 18\[Someone]\Dataset\Data Primer\video\drowsy\glasses\2_female_glasses_drowsy_1.avi"

cap = cv2.VideoCapture(video_path)

# Get the current FPS of the camera
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Print the FPS
print("Camera FPS:", fps)

# Initiate face model
with mp_facemesh.FaceMesh(
    static_image_mode=False,        # Default=False
    max_num_faces=1,                # Default=1
    refine_landmarks=False,         # Default=False
    min_detection_confidence=0.5,   # Default=0.5
    min_tracking_confidence= 0.5,   # Default=0.5
) as face_mesh:
    
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        imgW = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        imgH = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        
        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make detections
        results = face_mesh.process(image).multi_face_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw Face Landmarks
        if results:
            for face_id, face_landmarks in enumerate(results):
                landmarks = face_landmarks.landmark
                EAR, _ = calculate_avg_ear(
                          landmarks, 
                          chosen_left_eye_idxs, 
                          chosen_right_eye_idxs, 
                          imgW, 
                          imgH
                      )
                
                EAR_data = {
                    "EAR": EAR
                }
                
                df = pd.DataFrame(EAR_data, index=[0])
                
                df = np.array(df['EAR'])
                
                EAR_reshape = df.reshape(-1, 1)
                
                # Feature scaling
                EAR_scaled = loaded_scaler.transform(EAR_reshape)
                
                # Predict using the loaded SVC model
                driver_status = loaded_svc_model.predict(EAR_scaled)
                
                driver_status = driver_status[0]
                
                duration += 1
                
                if driver_status == 'drowsy':
                    drowsy_frame += 1
                    data_EAR_drowsy.append(EAR)
                    
                if driver_status == 'awake':
                    data_EAR_awake.append(EAR)
                    if drowsy_frame > 0 & drowsy_frame <= max_drowsy_frame:
                        drowsy_frame = drowsy_frame - 1
                    if drowsy_frame > max_drowsy_frame:
                        drowsy_frame = max_drowsy_frame
                    if drowsy_frame <= 15:
                        alarm_sound.stop()
    
                if drowsy_frame >= 30:
                    cv2.putText(image,
                               'ALERT, ALERT, ALERT',
                               (150,150),
                                cv2.FONT_HERSHEY_COMPLEX,
                                0.9, (255, 255, 255), 2
                               )
                
                    alarm_sound.play()
                
                # Append EAR Value and Driver Status
                data_EAR.append(EAR)
                data_status.append(driver_status)
                data_duration.append(duration)
                
                # Print the EAR Value and Driver Status
                print(f"EAR: {round(EAR, 2)}, Driver Status: {driver_status}, Drowsy Frame: {drowsy_frame}")
                
                # Put the EAR value in Video Frame
                cv2.putText(image, 
                            f"EAR: {round(EAR, 2)}", (1, 24),
                            cv2.FONT_HERSHEY_COMPLEX, 
                            0.9, (255, 255, 255), 2
                )
                
                # Put the Awake / Drowsy Status in Video Frame
                cv2.putText(image,
                           f"Driver status: {driver_status}",
                           (1,48),
                           cv2.FONT_HERSHEY_COMPLEX,
                           0.9, (255, 255, 255), 2)
                
                # Put the Number of Drowsy Frame in Video Frame
                cv2.putText(image,
                           f"Drowsy Frame: {drowsy_frame}",
                           (1,72),
                           cv2.FONT_HERSHEY_COMPLEX,
                           0.9, (255, 255, 255), 2)
                
        cv2.imshow("Webcam Feed", image)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Camera FPS: 30
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 2
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 3
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 4
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 5
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 6
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 7
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 8
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 9
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 10
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 11
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 12
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 13
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 14
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 15
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 16
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 17
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 18
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 19
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 20
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 21
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 22
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 23
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 24
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 25
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 26
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 27
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 28
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 29
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 30
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 31
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 32
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 33
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 34
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 35
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 36
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 37
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 38
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 39
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 40
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 41
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 42
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 43
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 44
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 45
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 46
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 47
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 48
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 49
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 50
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 51
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 52
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 53
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 54
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 55
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 56
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 57
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 58
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 59
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 60
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 61
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 62
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 63
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 64
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 65
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 66
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 67
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 68
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 69
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 70
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 71
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 72
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 73
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 74
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 75
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 76
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 77
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 78
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 79
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 80
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 81
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 82
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 83
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 84
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 85
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 86
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 87
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 88
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 89
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 90
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 91
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 92
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 93
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 94
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 95
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 96
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 97
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 98
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 99
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 100
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 101
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 102
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 103
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 104
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 105
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 106
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 107
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 108
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 109
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 110
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 111
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 112
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 113
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 114
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 115
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 116
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 117
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 118
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 119
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 120
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 121
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 122
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 123
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 124
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 125
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 126
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 127
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 128
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 129
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 130
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 131
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 132
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 133
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 134
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 135
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 136
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 137
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 138
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 139
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 140
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 141
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 142
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 143
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 144
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 145
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 146
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 147
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 148
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 149
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 150
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 151
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 152
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 153
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 154
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 155
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 156
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 157
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 158
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 159
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 160
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 161
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 162
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 163
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 164
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 165
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 166
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 167
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 168
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 169
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 170
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 171
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 172
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 173
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 174
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 175
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 176
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 177
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 178
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 179
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 180

# %% [markdown]
# ## 4.2. Make Detection in Real Time

# %% [markdown]
# - Mendefinisikan fungsi **set_resolution_with_aspect_ratio** untuk mengubah ukuran dan rasio dari frame kamera

# %%
def set_resolution_with_aspect_ratio(cap, target_height, aspect_ratio):
    # Calculate the corresponding width to maintain the aspect ratio
    target_width = int(target_height * aspect_ratio)

    # Set the desired resolution
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, target_width)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, target_height)

# %% [markdown]
# - Mengecek kondisi dan posisi tampilan kamera

# %%
cap = cv2.VideoCapture(0)

# Set the resolution 
# set_resolution_with_aspect_ratio(cap, 720, 4/3)

# Add a delay to allow the camera to initialize (optional)
cv2.waitKey(1000)  # 1-second delay

# Get the resolution and fpsto confirm the change
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(f"Camera resolution: {width} x {height}")
print(f"Frames per second: {fps}")

while True:
    ret, frame = cap.read()

    cv2.imshow('frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Camera resolution: 640 x 480
# Frames per second: 30.0

# %% [markdown]
# - Mendefinisikan variabel yang digunakan dalam proses deteksi

# %%
data_EAR = []
data_EAR_awake = []
data_EAR_drowsy = []
data_status = []
data_duration = []
max_drowsy_frame = 45

# %% [markdown]
# - Menjalankan proses deteksi secara _real time_ melalui kamera

# %%
drowsy_frame = 0
duration = 0

cap = cv2.VideoCapture(0)

# Set the resolution 
#set_resolution_with_aspect_ratio(cap, 720, 4/3)

# Get the current FPS of the camera
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Print the FPS
print("Camera FPS:", fps)

# Initiate face model
with mp_facemesh.FaceMesh(
    static_image_mode=False,        # Default=False
    max_num_faces=1,                # Default=1
    refine_landmarks=False,         # Default=False
    min_detection_confidence=0.5,   # Default=0.5
    min_tracking_confidence= 0.5,   # Default=0.5
) as face_mesh:
    
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        imgW = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        imgH = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        
        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make detections
        results = face_mesh.process(image).multi_face_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw Face Landmarks
        if results:
            for face_id, face_landmarks in enumerate(results):
                landmarks = face_landmarks.landmark
                EAR, _ = calculate_avg_ear(
                          landmarks, 
                          chosen_left_eye_idxs, 
                          chosen_right_eye_idxs, 
                          imgW, 
                          imgH
                      )
                
                EAR_data = {
                    "EAR": EAR
                }
                
                df = pd.DataFrame(EAR_data, index=[0])
                
                df = np.array(df['EAR'])
                
                EAR_reshape = df.reshape(-1, 1)
                
                # Feature scaling
                EAR_scaled = loaded_scaler.transform(EAR_reshape)
                
                # Predict using the loaded SVC model
                driver_status = loaded_svc_model.predict(EAR_scaled)
                
                driver_status = driver_status[0]
                
                duration += 1
                
                if driver_status == 'drowsy':
                    drowsy_frame += 1
                    data_EAR_drowsy.append(EAR)
                    
                if driver_status == 'awake':
                    data_EAR_awake.append(EAR)
                    if drowsy_frame > 0 & drowsy_frame <= max_drowsy_frame:
                        drowsy_frame = drowsy_frame - 1
                    if drowsy_frame > max_drowsy_frame:
                        drowsy_frame = max_drowsy_frame
                    if drowsy_frame <= 15:
                        alarm_sound.stop()
    
                if drowsy_frame >= 30:
                    cv2.putText(image,
                               'ALERT, ALERT, ALERT',
                               (150,150),
                                cv2.FONT_HERSHEY_COMPLEX,
                                0.9, (255, 255, 255), 2
                               )
                
                    alarm_sound.play()
                
                # Append EAR Value and Driver Status
                data_EAR.append(EAR)
                data_status.append(driver_status)
                data_duration.append(duration)
                
                # Print the EAR Value and Driver Status
                print(f"EAR: {round(EAR, 2)}, Driver Status: {driver_status}, Drowsy Frame: {drowsy_frame}")
                
                # Put the EAR value in Video Frame
                cv2.putText(image, 
                            f"EAR: {round(EAR, 2)}", (1, 24),
                            cv2.FONT_HERSHEY_COMPLEX, 
                            0.9, (255, 255, 255), 2
                )
                
                # Put the Awake / Drowsy Status in Video Frame
                cv2.putText(image,
                           f"Driver status: {driver_status}",
                           (1,48),
                           cv2.FONT_HERSHEY_COMPLEX,
                           0.9, (255, 255, 255), 2)
                
                # Put the Number of Drowsy Frame in Video Frame
                cv2.putText(image,
                           f"Drowsy Frame: {drowsy_frame}",
                           (1,72),
                           cv2.FONT_HERSHEY_COMPLEX,
                           0.9, (255, 255, 255), 2)
                
        cv2.imshow("Webcam Feed", image)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Camera FPS: 30
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.44, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.43, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.38, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 2
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 1
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 2
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 1
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 2
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 3
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 4
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 5
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 6
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 7
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 8
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 9
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 10
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 11
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 12
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 13
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 14
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 15
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 16
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 17
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 18
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 19
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 20
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 21
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 22
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 23
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 24
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 25
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 26
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 27
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 28
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 29
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 30
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 31
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 32
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 33
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 34
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 35
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 36
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 37
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 38
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 39
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 40
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 41
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 42
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 43
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 44
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 45
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 46
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 47
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 48
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 49
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 50
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 51
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 52
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 53
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 54
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 45
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 44
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 43
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 42
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 41
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 40
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 39
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 38
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 37
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 36
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 35
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 34
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 33
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 32
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 31
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 30
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 29
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 28
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 29
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 30
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 29
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 28
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 27
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 26
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 25
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 24
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 23
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 22
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 21
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 20
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 19
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 18
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 17
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 16
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 15
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 14
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 13
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 12
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 11
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 10
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 9
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 8
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 7
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 6
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 5
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 4
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 3
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 2
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 1
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.37, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.38, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.19, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 2
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 3
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 4
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 3
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 2
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 1
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.37, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# ...
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 33
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 34
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 35
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 36
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 37
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 38
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 39
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 40
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 41
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 42
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 43
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 42
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 41
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 40
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 39
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 38
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 37
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 36
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 35
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 34
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 33
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 32
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 31
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 30
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 29
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 28
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 27
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 26
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 25
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 24
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 23
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 22
# EAR: 0.37, Driver Status: awake, Drowsy Frame: 21
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 20
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 19
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 18
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 17
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 16
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 15
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 14
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 13
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 12
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 11
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 10
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 9
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 8
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 7
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 6
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 5
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 4
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 3
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 2
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 1
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.36, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.35, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.34, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.33, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.25, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.24, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.21, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 1
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 2
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 3
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 4
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 5
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 6
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 7
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 8
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 9
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 10
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 11
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 12
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 13
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 14
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 15
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 16
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 17
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 18
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 19
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 20
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 21
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 22
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 23
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 24
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 25
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 26
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 27
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 28
# EAR: 0.15, Driver Status: drowsy, Drowsy Frame: 29
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 30
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 31
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 32
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 33
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 34
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 35
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 36
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 37
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 38
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 39
# EAR: 0.16, Driver Status: drowsy, Drowsy Frame: 40
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 41
# EAR: 0.18, Driver Status: drowsy, Drowsy Frame: 42
# EAR: 0.17, Driver Status: drowsy, Drowsy Frame: 43
# EAR: 0.22, Driver Status: awake, Drowsy Frame: 42
# EAR: 0.23, Driver Status: awake, Drowsy Frame: 41
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 40
# EAR: 0.26, Driver Status: awake, Drowsy Frame: 39
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 38
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 37
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 36
# EAR: 0.27, Driver Status: awake, Drowsy Frame: 35
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 34
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 33
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 32
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 31
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 30
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 29
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 28
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 27
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 26
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 25
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 24
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 23
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 22
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 21
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 20
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 19
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 18
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 17
# EAR: 0.21, Driver Status: drowsy, Drowsy Frame: 18
# EAR: 0.2, Driver Status: drowsy, Drowsy Frame: 19
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 18
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 17
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 16
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 15
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 14
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 13
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 12
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 11
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 10
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 9
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 8
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 7
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 6
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 5
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 4
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 3
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 2
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 1
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.3, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.28, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.29, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.32, Driver Status: awake, Drowsy Frame: 0
# EAR: 0.31, Driver Status: awake, Drowsy Frame: 0
